# %% [markdown]
# ## 00. Questions/Ideas/Insights/Learning Outcomes
#
# 01. How to create engine for mysql in jupyter notebook?
# 02. Difference between `GROUP BY` and `PARTITION BY`?
# 03. What did `ProgrammingError` meant here?

# %% [markdown]
# ## 01. Installing Libraries

# %%
import pandas as pd
import sqlalchemy
import pymysql

# %% [markdown]
# ## 02. Creating Engine

# %%
engine = sqlalchemy.create_engine('mysql+pymysql://root:Zizaniut56@localhost:3306/exercises')

# %% [markdown]
# ## 03. Running Query

# %% [markdown]
# ### 03.01. Stratascratch (ID 9917)- Salesforce,Glassdoor
#
#
# Question: Compare each employee's salary with the average salary of the corresponding department.
# Output the department, first name, and salary of employees along with the average salary of that department.
#
#
#
# ![image.png](attachment:image.png)

# %%
query = '''
SELECT
    department,
    first_name,
    salary,
    AVG(salary) OVER (Partition by department) AS "Average Salary Per Department"

FROM employee

'''

df = pd.read_sql(query,engine)
df
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# File ~\anaconda3\lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     151 query = self.mogrify(query, args)
# ...

# %% [markdown]
# ### 03.01.01. Why this error happened?
#
# This error message indicates that the `exercises.employee` table doesn't exist in the database. Anyways,
#
# our query is correct.
